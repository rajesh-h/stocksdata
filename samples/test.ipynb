# %%
import investpy

# %%
stock_company_profile = investpy.get_stock_company_profile(stock='infy',country='india')

# %%
stock_devidends = investpy.get_stock_dividends(stock='infy',country='india')

# %%
stock_company_fin_summ_incm_stat_annual = investpy.get_stock_financial_summary(stock='infy',country='india',summary_type='income_statement', period='annual')

# %%
stock_company_fin_summ_cash_flow_annual = investpy.get_stock_financial_summary(stock='infy',country='india',summary_type='cash_flow_statement', period='annual')

# %%
stock_company_fin_summ_balance_sheet_annual = investpy.get_stock_financial_summary(stock='infy',country='india',summary_type='balance_sheet', period='annual')

# %%
stock_company_fin_summ_incm_stat_quarter = investpy.get_stock_financial_summary(stock='infy',country='india',summary_type='income_statement', period='quarterly')

# %%
stock_company_fin_summ_cash_flow_quarter = investpy.get_stock_financial_summary(stock='infy',country='india',summary_type='cash_flow_statement', period='quarterly')

# %%
stock_company_fin_summ_balance_sheet_quarterly = investpy.get_stock_financial_summary(stock='infy',country='india',summary_type='balance_sheet', period='quarterly')

# %%
stock_history_data = investpy.get_stock_historical_data(stock='infy',country='india', from_date='20/11/2020', to_date='10/12/2020',interval='Daily')

# %%
stock_information = investpy.get_stock_information(stock='infy',country='india')

# %%
stocks_list = investpy.get_stocks(country='india')

# %%
stocks_overview = investpy.get_stocks_overview(country='india',as_json=False, n_results=100)

# %%
stocks_recent_data = investpy.get_stock_recent_data(stock='infy',country='india')

# %%
# Out:
#                Open     High      Low    Close    Volume Currency
# Date
# 2020-11-17  1144.75  1145.00  1112.65  1123.70  12813968      INR
# 2020-11-18  1128.50  1132.70  1101.45  1110.55   9839468      INR
# 2020-11-19  1100.00  1114.70  1093.80  1096.75  10092343      INR
# 2020-11-20  1106.00  1109.00  1091.10  1103.35   8063554      INR
# 2020-11-23  1105.00  1144.80  1101.95  1139.85  10546363      INR
# 2020-11-24  1145.00  1154.90  1133.35  1140.05   8515426      INR
# 2020-11-25  1137.00  1143.50  1111.25  1115.65   8958701      INR
# 2020-11-26  1119.95  1119.95  1098.30  1113.20  10962256      INR
# 2020-11-27  1118.00  1121.00  1091.00  1100.00  25306144      INR
# 2020-12-01  1105.05  1140.25  1105.05  1137.85   8933802      INR
# 2020-12-02  1134.00  1147.45  1121.00  1140.90   6741637      INR
# 2020-12-03  1147.00  1147.00  1122.70  1126.45  16212632      INR
# 2020-12-04  1125.00  1137.00  1115.00  1134.65  10564055      INR
# ...
